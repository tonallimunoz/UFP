# %%
import pandas as pd
from dateutil import parser
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy.ma as ma

# %%
CPC = pd.read_csv("outputcorrección.txt", delimiter = "\t")
CPC.index = pd.date_range('4/1/2017', periods = 780770, freq ='S')
CPCtotal = pd.to_numeric(CPC['CPC']);
CPCpromedio = (CPCtotal.groupby(CPCtotal.index.hour).mean())

# %%
sumafina = pd.read_csv("channelsumafina.txt", delimiter="\t")
sumafina.index = [parser.parse(b) for b in sumafina['start']]     
del sumafina['start']
sumafinapromedio = sumafina.groupby(sumafina.index.hour).mean()

# %%
fig, ax1 = plt.subplots(figsize=(9,4))

ax1.set_xlabel('Hour')
ax1.set_ylabel('Particle concentration (p/cm³)')

lns1 = ax1.plot(CPCpromedio, color = "black", label = "CPC")
lns2 = ax1.plot(sumafinapromedio, color = "black", linestyle = 'dashdot', label = "UFPM")

lns = lns1+lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=1)

# %%
sumafinapromedio = pd.to_numeric(sumafinapromedio['SUMA']);

# %%
ma.corrcoef(ma.masked_invalid(CPCpromedio), ma.masked_invalid(sumafinapromedio))
# Out:
# masked_array(
#   data=[[1.0, 0.8671627608249975],
#         [0.8671627608249975, 1.0]],
#   mask=[[False, False],
#         [False, False]],
#   fill_value=1e+20)

# %%
CPC2 = pd.read_csv("outputcorrección2.txt", delimiter = "\t")
CPC2.index = pd.date_range('4/1/2017', periods = 520505, freq ='S')
CPCtotal2 = pd.to_numeric(CPC2['CPC']);
CPCpromedio2 = (CPCtotal2.groupby(CPCtotal2.index.hour).mean())

# %%
sumafina2 = pd.read_csv("channelsumafina2.txt", delimiter="\t")
sumafina2.index = [parser.parse(b) for b in sumafina2['start']]     
del sumafina2['start']
sumafinapromedio2 = sumafina2.groupby(sumafina2.index.hour).mean()

# %%
fig, ax1 = plt.subplots(figsize=(9,4))

ax1.set_xlabel('Hour')
ax1.set_ylabel('Particle concentration (p/cm³)')

lns1 = ax1.plot(CPCpromedio2, color = "black", label = "CPC")
lns2 = ax1.plot(sumafinapromedio2, color = "black", linestyle = 'dashdot', label = "UFPM")

lns = lns1+lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=1)

# %%
sumafinapromedio2 = pd.to_numeric(sumafinapromedio2['SUMA']);

# %%
ma.corrcoef(ma.masked_invalid(CPCpromedio2), ma.masked_invalid(sumafinapromedio2))
# Out:
# masked_array(
#   data=[[1.0, 0.9248767151166811],
#         [0.9248767151166811, 1.0]],
#   mask=[[False, False],
#         [False, False]],
#   fill_value=1e+20)

# %%
CPC3 = pd.read_csv("outputcorrección3.txt", delimiter = "\t")
CPC3.index = pd.date_range('4/1/2017', periods = 346974, freq ='S')
CPCtotal3 = pd.to_numeric(CPC3['CPC']);
CPCpromedio3 = (CPCtotal3.groupby(CPCtotal3.index.hour).mean())

# %%
sumafina3 = pd.read_csv("channelsumafina3.txt", delimiter="\t")
sumafina3.index = [parser.parse(b) for b in sumafina3['start']]     
del sumafina3['start']
sumafinapromedio3 = sumafina3.groupby(sumafina3.index.hour).mean()

# %%
fig, ax1 = plt.subplots(figsize=(9,4))

ax1.set_xlabel('Hour')
ax1.set_ylabel('Particle concentration (p/cm³)')

lns1 = ax1.plot(CPCpromedio3, color = "black", label = "CPC")
lns2 = ax1.plot(sumafinapromedio3, color = "black", linestyle = 'dashdot', label = "UFPM")

lns = lns1+lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=1)

# %%
sumafinapromedio3 = pd.to_numeric(sumafinapromedio3['SUMA']);

# %%
ma.corrcoef(ma.masked_invalid(CPCpromedio3), ma.masked_invalid(sumafinapromedio3))
# Out:
# masked_array(
#   data=[[1.0, 0.9608046641555671],
#         [0.9608046641555671, 1.0]],
#   mask=[[False, False],
#         [False, False]],
#   fill_value=1e+20)
